# %%
# Out:
# REMQ para 0 graus: 0.6247711581051097
# REMQ para 45 graus: 1.767112899619037
# REMQ para 90 graus: 2.0801127373293986

# %%
# Importando as bibliotecas necessárias
import matplotlib.pyplot as plt
import numpy as np

# Dados fornecidos
angulos1 = [0.61, 0.55, 0.75, 0.53, 0.68, 0.71, 0.87, 0.53, 0.39, 0.35, 0.58, 0.49, 0.83, 0.90, 0.65, 0.84, 0.18, 0.63, 0.63, 0.88, 0.43, 0.47, 0.56, 0.57, 0.55, 0.76, 0.92, 0.53, 0.48, 0.62, 0.31, 0.46, 0.46, 0.54, 0.54, 0.56, 0.58, 0.71, 0.66, 0.54, 0.67, 0.80, 0.47, 0.45, 0.39, 0.67, 0.68, 0.42, 0.71, 0.65, 0.43, 0.40, 0.87, 0.80, 0.76, 0.56, 0.37, 0.38, 0.99, 0.82, 0.56, 0.43, 0.49, 0.52, 0.73, 0.71, 0.61, 0.50, 0.56, 0.65, 0.70, 0.64, 0.85, 0.64, 0.71, 0.54, 0.52, 0.50, 0.61, 0.74, 0.67, 0.33, 0.58, 0.43, 0.85, 0.75, 0.35, 0.81, 0.92, 0.54, 0.53, 0.57, 0.46, 0.46, 0.88, 0.62, 0.61, 0.74, 0.26, 0.64]
angulos2 = [42.84, 42.51, 42.81, 42.66, 42.79, 42.88, 43.85, 43.54, 43.40, 43.04, 42.86, 43.80, 44.03, 43.30, 43.18, 42.85, 43.41, 43.00, 43.36, 43.27, 43.29, 42.90, 42.79, 43.06, 42.97, 42.76, 43.29, 43.77, 43.44, 43.30, 42.45, 43.02, 43.11, 43.75, 42.57, 42.91, 43.09, 43.47, 43.28, 43.21, 42.81, 43.36, 43.03, 43.77, 43.82, 42.90, 43.12, 43.14, 43.41, 43.80, 43.10, 43.20, 43.52, 43.25, 43.21, 43.30, 43.13, 43.58, 43.68, 43.28, 43.14, 43.21, 43.50, 43.69, 43.04, 43.05, 43.63, 43.23, 43.60, 43.18, 43.25, 43.27, 43.49, 43.14, 43.79, 43.66, 43.67, 42.87, 43.51, 43.37, 43.39, 43.24, 43.18, 43.55, 43.32, 43.38, 43.45, 43.39, 43.29, 43.65, 43.50, 43.34, 43.11, 43.24, 43.00, 43.19, 43.26, 42.95, 43.55, 43.73]
angulos3 = [87.65, 87.58, 87.85, 88.06, 88.14, 88.36, 87.90, 87.81, 88.06, 88.06, 88.07, 88.00, 87.80, 87.56, 88.32, 88.03, 87.57, 87.68, 87.80, 88.37, 88.23, 88.10, 87.43, 88.07, 87.66, 87.71, 87.92, 87.62, 88.11, 87.72, 87.83, 88.06, 88.32, 88.35, 87.68, 87.85, 88.20, 87.83, 87.35, 87.86, 87.98, 87.60, 87.78, 88.03, 88.39, 88.30, 87.33, 87.49, 87.73, 87.88, 87.91, 87.61, 88.26, 88.16, 88.38, 87.07, 87.39, 88.42, 88.36, 88.18, 87.91, 88.41, 88.14, 88.15, 87.63, 88.47, 87.72, 87.61, 87.91, 88.28, 88.14, 87.52, 87.76, 87.82, 88.32, 87.49, 88.61, 87.65, 87.70, 87.66, 88.13, 88.29, 87.81, 88.00, 88.12, 87.88, 87.75, 87.96, 87.72, 88.19, 87.60, 87.84, 88.03, 88.40, 87.77, 88.50, 88.13, 88.29, 88.00, 88.12]

# Valores de referência
ref1 = [0]*len(angulos1)
ref2 = [45]*len(angulos2)
ref3 = [90]*len(angulos3)

# Calcular o REMQ para cada conjunto de ângulos
remq1 = np.sqrt(np.mean((np.array(angulos1) - np.array(ref1))**2))
remq2 = np.sqrt(np.mean((np.array(angulos2) - np.array(ref2))**2))
remq3 = np.sqrt(np.mean((np.array(angulos3) - np.array(ref3))**2))

# Criando o gráfico
plt.figure(figsize=(10, 6))
plt.plot([remq1]*len(angulos1), label='REMQ para 0 graus')
plt.plot([remq2]*len(angulos2), label='REMQ para 45 graus')
plt.plot([remq3]*len(angulos3), label='REMQ para 90 graus')
plt.ylim(-5, 10)
plt.yticks(np.arange(-5, 5, 5))
plt.title('Gráfico da Raiz do Erro Quadrático Médio (REMQ)')
plt.xlabel('Índice')
plt.ylabel('REMQ')
plt.legend()
plt.show()
